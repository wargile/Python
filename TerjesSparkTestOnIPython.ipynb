# %%
"""
Testing iPython Notebooks on Spark instance running on local PC

Spark UI on Sandbox or localhost:
http://sandbox.hortonworks.com:4040/jobs/
http://<sandbox ip-address>:4040/jobs/
http://localhost:4040/jobs/

iPython on Spark:
http://ramhiser.com/2015/02/01/configuring-ipython-notebook-support-for-pyspark/

Start iPython with PySpark profile from c:\coding\python to get notebooks from there:
c:\python27\scripts\ipython notebook --profile=pyspark

Run notebook server:
http://localhost:42424/tree
"""

import os
#import sys
import glob
import re
import math
import matplotlib.pyplot as plt # http://matplotlib.org/users/customizing.html
#import operator
from operator import add
from pyspark import SparkContext, SparkConf
from pyspark.sql import SQLContext, HiveContext, Row
from pyspark.sql.types import *
#from ast import literal_eval

# Line below is not necessary, as Spark shell pre-loads the SparkContext sc object
# sc = SparkContext( 'local', 'pyspark')

# %matplotlib inline

spark_home = os.environ.get('SPARK_HOME', None)
print('SPARK initialized OK! The SPARK home directory is: ' + spark_home)
# Get the Spark version number from the SparkContext
# sc.version.split("\\.")
print 'Spark version is {0}'.format(sc.version)

sqlContext.setConf("spark.sql.codegen", "true")
sqlContext.setConf("spark.sql.unsafe.enabled", "true") # Project Tungsten - experimental!
sqlContext.setConf("spark.shuffle.manager", "tungsten-sort")
# Out:
# SPARK initialized OK! The SPARK home directory is: c:\spark
# Spark version is 1.5.0-SNAPSHOT

# %%
# Use README.md from Spark home dir
# text_file = sc.textFile(spark_home + '\README.md')
# the_title = 'README.md'
# Use Shakespeare.txt from c:/coding/hadoop/pig/MapReduceInputData
text_file = sc.textFile('C:\coding\Hadoop\pig\MapReduceInputData\CompleteShakespeare.txt')
the_title = 'Shakespeare\'s Complete Works'

# %%
# Get separate words by regex, lowercase 'em, count 'em and sort 'em DESC
word_counts = text_file \
    .flatMap(lambda line: [w.lower() for w in re.compile("([\w][\w]*'?\w?)").findall(line)]) \
    .map(lambda word: (word, 1)) \
    .reduceByKey(lambda a, b: a + b).map(lambda (a, b): (b, a)).sortByKey(False, 1).map(lambda (a, b): (b, a)).cache()

n = 35
print word_counts.collect()[0:n]
highfreq_words = word_counts.collect()[0:n]
words = [w for (w, f) in highfreq_words]
frequency = [f for (w, f) in highfreq_words]
# Out:
# [(u'the', 27595), (u'and', 26735), (u'i', 20346), (u'to', 19659), (u'of', 18124), (u'a', 14721), (u'you', 13622), (u'my', 12490), (u'that', 11131), (u'in', 10996), (u'is', 9567), (u'not', 8728), (u'for', 8226), (u'with', 7995), (u'me', 7771), (u'it', 7692), (u'be', 7083), (u'your', 6874), (u'his', 6859), (u'this', 6821), (u'but', 6277), (u'he', 6258), (u'as', 5961), (u'have', 5884), (u'thou', 5489), (u'so', 5270), (u'him', 5204), (u'will', 4974), (u'what', 4469), (u'by', 4418), (u'thy', 4034), (u'all', 3923), (u'her', 3849), (u'are', 3839), (u'no', 3792)]

# %%
# Plot a figure of highest freq. words
fig, axes = plt.subplots(figsize=(15, 4), frameon=False, facecolor='white', edgecolor='white')
# plt.style.use('ggplot')
plt.axis([0, len(words), 0, max(frequency)])
plt.grid(b=True, which='major', axis='y')
plt.xlabel('Words')
plt.ylabel('Frequency')
plt.bar(range(0, len(frequency)), frequency, alpha=0.75, color='#00bbaa')

y_axis_interval = int(math.floor(max(frequency) / 5))
for axis, ticks in [(axes.get_xaxis(), range(0, len(words))), (axes.get_yaxis(), range(0, max(frequency), y_axis_interval))]:
        axis.set_ticks_position('none')
        axis.set_ticks(ticks)
        axis.label.set_color('#666666')

axes.set_title(the_title + ' most frequent words')
axes.set_xticklabels(words, rotation=35, ha='right')

plt.show()

# %%
vector1 = (2,3,5)
vector2 = (3,4,6)
vector1 = 2
vector2 = 6
# print zip(vector1, vector2)

# Get dot product
def dotprod(a, b):
    if not isinstance(a, tuple):
        return a * b
    else:
        return sum(a * b for a, b in zip(vector1, vector2))

# Get vector norm
def norm(a):
    if not isinstance(a, tuple):
        return a
    else:
        return math.sqrt(sum(x**2 for x in a))

# Get Euclidean Distance between two vectors (NOTE: this does not give the same result as R and WolframAlpha!)
def euclidean_distance1(a, b):
    return dotprod(a, b) / (norm(a) * norm(b))

# Get Euclidean Distance between two vectors - R style (gives correct result)
def euclidean_distance2(a, b):
    if not isinstance(a, tuple):
        return math.sqrt((a - b)**2)
    else:
        return math.sqrt(sum([(x - y)**2 for (x, y) in zip(vector1, vector2)]))

print "Dot product of two vectors: {0}".format(dotprod(vector1, vector2))
print "Norm of vector: {0}".format(round(norm(vector1), 4))
print "Eclidean distance of two vectors: {0}".format(euclidean_distance1(vector1, vector2))
print "Eclidean distance of two vectors: {0}".format(euclidean_distance2(vector1, vector2))
# Out:
# Dot product of two vectors: 12
# Norm of vector: 2.0
# Eclidean distance of two vectors: 1
# Eclidean distance of two vectors: 4.0

# %%
word_count_thou = text_file \
    .flatMap(lambda line: [w.lower() for w in re.compile("([\w][\w]*'?\w?)").findall(line)]) \
    .filter(lambda word: word == 'thou').count()

print 'Word \'thou\' occured ' + str(word_count_thou) + ' times.'

word_count_thou = text_file \
    .flatMap(lambda line: [w.lower() for w in re.compile("([\w][\w]*'?\w?)").findall(line)]) \
    .filter(lambda word: word in ['thou','thy','thine']).map(lambda a: (a, 1)).reduceByKey(lambda a, b: a + b)

word_count_display = [c for (w, c) in word_count_thou.take(3)]
print 'Words \'thou\',\'thy\',\'thine\' occured ' + str(word_count_display) + ' times.'
# Out:
# Word 'thou' occured 5489 times.
# Words 'thou','thy','thine' occured [5489, 4034, 454] times.

# %%
# Create a simple, filled lineplot
print word_count_display
plt.fill(range(3), word_count_display, 'r', alpha=.4)
plt.grid(True)
plt.show()
# Out:
# [5489, 4034, 454]

# %%
my_id_url_tokens = [(('id1','url1'), ['T1','T2']),(('id2','url2'), ['T1','T2']),(('id1','url1'), ['T3','T4'])]
print my_id_url_tokens
tokenRDD = sc.parallelize(my_id_url_tokens)
print "reduceByKey: ", tokenRDD.map(lambda (a, b): (a, b)).reduceByKey(lambda a, b: a + b).collect()
print "groupByKey: ", tokenRDD.map(lambda (a, b): (a, b)).groupByKey().mapValues(list).collect()
#tokenRDD.map(lambda value: (value, 1)).collect()
# TODO: Learn combineByKey()
# Out:
# [(('id1', 'url1'), ['T1', 'T2']), (('id2', 'url2'), ['T1', 'T2']), (('id1', 'url1'), ['T3', 'T4'])]
# reduceByKey:
# [(('id1', 'url1'), ['T1', 'T2', 'T3', 'T4']), (('id2', 'url2'), ['T1', 'T2'])]
# groupByKey:
# [(('id1', 'url1'), [['T1', 'T2'], ['T3', 'T4']]), (('id2', 'url2'), [['T1', 'T2']])]

# %%
# https://spark.apache.org/docs/latest/sql-programming-guide.html
data = sc.textFile('C:\coding\Hadoop\pig\MapReduceInputData\moves_activities_3.csv')
# Get a file to play around with data frames on
# print data.take(2)
# Convert each line into a tuple
parts = data.map(lambda l: l.split(","))
# print parts.take(3)
# Columns: id,Date,Activity,Group,Start,End,Duration,Distance,Steps,Calories
activities = parts.map(lambda p: [p[0],p[1],p[2],p[3],p[4],p[5],int(p[6]),float(p[7]),int(p[8]),p[9]]) \
                       .filter(lambda p: p[2] == 'walking')

schema = StructType([ \
    StructField("id", StringType(), True), \
    StructField("date", StringType(), True), \
    StructField("activity", StringType(), True), \
    StructField("group", StringType(), True), \
    StructField("start", StringType(), True), \
    StructField("end", StringType(), True), \
    StructField("duration", IntegerType(), True), \
    StructField("distance", FloatType(), True), \
    StructField("steps", IntegerType(), True), \
    StructField("calories", StringType(), True)])

activities_df = sqlContext.createDataFrame(activities, schema)

# Register the DataFrame as a table
activities_df.registerTempTable('activities')

# SQL can be run over DataFrames that have been registered as a table
results = sqlContext.sql('SELECT date, steps, activity FROM activities ORDER BY steps DESC')

# The results of SQL queries are RDDs and support all the normal RDD operations
steps = results.map(lambda p: 'Date: ' + str(p.date) + ' Steps: ' + str(p.steps) + ' Activity: ' + str(p.activity))
for step in steps.collect()[0:5]:
  print step
# Out:
# Date: 16.11.2014 Steps: 6223 Activity: walking
# Date: 09.11.2014 Steps: 5267 Activity: walking
# Date: 09.11.2014 Steps: 4468 Activity: walking
# Date: 07.11.2014 Steps: 2747 Activity: walking
# Date: 31.10.2014 Steps: 2584 Activity: walking

# %%
steps_display = results.map(lambda p: (p.date, p.steps)).collect()

# %%
# http://matplotlib.org/examples/pylab_examples/line_styles.html
def display_steps(steps_display, n):
    date = [d for (d, s) in steps_display][0:n]
    steps = [s for (d, s) in steps_display][0:n]

    fig, axes = plt.subplots(figsize=(16, 4), frameon=False, facecolor='white', edgecolor='white')
    plt.axis([-0.2, n, 0, max(steps)+200])
    plt.grid(b=True, which='major', axis='both')
    plt.xlabel('Date')
    plt.ylabel('Steps')
    plt.plot(steps, color='#00bbaa', marker='o')

    y_axis_interval = int(math.floor(max(steps) / 5))
    for axis, ticks in [(axes.get_xaxis(), range(0, n)), (axes.get_yaxis(), range(0, max(steps), y_axis_interval))]:
            axis.set_ticks_position('none')
            axis.set_ticks(ticks)
            #axis.label.set_color('#666666')
            axis.label.set_fontsize(12)

    axes.set_title('Walking, steps', fontsize=16)
    axes.set_xticklabels(date, rotation=35, ha='right', fontsize=9)
    plt.show()

# %%
# NOTE: There are 105 steps
display_steps(steps_display, 35)

results = sqlContext.sql('SELECT date, steps FROM activities ORDER BY date')
steps_display = results.map(lambda p: (p.date, p.steps)).collect()

display_steps(steps_display, 40)

# %%
#activities_df.show()
print activities_df.head(n=3)
activities_df.head(n=1)[0][1] # Get the data from the Row tuple object
# Out:
# [Row(id=u'1', date=u'23.10.2014', activity=u'walking', group=u'walking', start=u'2014-10-23T15:30:26+02:00', end=u'2014-10-23T15:39:35+02:00', duration=549, distance=0.6539999842643738, steps=909, calories=u'0'), Row(id=u'3', date=u'23.10.2014', activity=u'walking', group=u'walking', start=u'2014-10-23T17:24:20+02:00', end=u'2014-10-23T17:26:55+02:00', duration=155, distance=0.17000000178813934, steps=226, calories=u'0'), Row(id=u'5', date=u'23.10.2014', activity=u'walking', group=u'walking', start=u'2014-10-23T17:51:52+02:00', end=u'2014-10-23T17:52:22+02:00', duration=30, distance=0.029999999329447746, steps=60, calories=u'0')]
# u'23.10.2014'

# %%
# https://spark.apache.org/docs/latest/sql-programming-guide.html#dataframe-operations
activities_df.printSchema()
result = activities_df.groupBy().avg('distance', 'duration').collect()
print result
print 'Average distance: ' + str(result[0][0]) + ' Average duration: ' + str(result[0][1]) # NOTE: Access elements in list[0]!
activities_df.filter(activities_df['steps'] > 3000).show()
# Out:
# root
#  |-- id: string (nullable = true)
#  |-- date: string (nullable = true)
#  |-- activity: string (nullable = true)
#  |-- group: string (nullable = true)
#  |-- start: string (nullable = true)
#  |-- end: string (nullable = true)
#  |-- duration: integer (nullable = true)
#  |-- distance: float (nullable = true)
#  |-- steps: integer (nullable = true)
#  |-- calories: string (nullable = true)
#
# [Row(AVG(distance)=0.47487619397274794, AVG(duration)=371.04761904761904)]
# Average distance: 0.474876193973 Average duration: 371.047619048
# +---+----------+--------+-------+--------------------+--------------------+--------+--------+-----+--------+
# | id|      date|activity|  group|               start|                 end|duration|distance|steps|calories|
# +---+----------+--------+-------+--------------------+--------------------+--------+--------+-----+--------+
# |117|09.11.2014| walking|walking|2014-11-09T10:24:...|2014-11-09T11:17:...|    3191|   4.445| 5267|       0|
# ...

# %%
# Parse a HTML document
# http://stackoverflow.com/questions/8644741/novice-python-regex-pull-strings-between-a-tags-using-regex

# -- In sandbox, get HTML data from Hortonworks page on Wikipedia:
# wget http://wikipedia.org/wiki/Hortonworks
# -- In PC git console, get HTML data from Hortonworks page on Wikipedia:
# curl https://en.wikipedia.org/wiki/Hortonworks > Hortonworks.html
# -- Put it on HDFS, or locally (locally in this example):
# hadoop fs -put ~/Hortonworks /user/guest/Hortonworks
# -- Start pyspark:
# pyspark

myLines = sc.textFile('file:///c:/coding/hadoop/pig/mapreduceinputdata/Hortonworks.html')
#myLines = sc.textFile('hdfs://127.0.0.1:9000/user/terje/Hortonworks.html')
myLines_filtered = myLines.filter( lambda x: len(x) > 0 )
# -- Find all <img> tags
imageLines = myLines_filtered.filter(lambda a: re.compile('\<\i\m\g').findall(a))
#imageLines = myLines_filtered.filter(lambda a: re.compile(r'<img.*?>(.*?)/>', re.S|re.M).findall(a))
print imageLines.take(2)
# TODO: Get the text between tags
# http://stackoverflow.com/questions/8644741/novice-python-regex-pull-strings-between-a-tags-using-regex
# Out:
# [u'<td colspan="2" class="logo" style="text-align:center"><a href="/wiki/File:Hortonworks_logo.gif" class="image"><img alt="Hortonworks logo.gif" src="//upload.wikimedia.org/wikipedia/en/3/33/Hortonworks_logo.gif" width="190" height="58" data-file-width="190" data-file-height="58" /></a></td>', u'<noscript><img src="//en.wikipedia.org/wiki/Special:CentralAutoLogin/start?type=1x1" alt="" title="" width="1" height="1" style="border: none; position: absolute;" /></noscript></div>\t\t\t\t\t<div class="printfooter">']

# %%
# Doing the IIS log
data = sc.textFile('file:///c:/coding/hadoop/pig/mapreduceinputdata/iis3.log')
#(client_ip:chararray, user_name:chararray, date:chararray, time:chararray, service_and_instance:chararray,
#    server_name:chararray, server_ip_address:chararray, time_taken:chararray, client_bytes_sent:chararray,
#    server_bytes_sent:chararray, service_status_code:chararray, windows_status_code:chararray,
#    request_type:chararray, target_of_operation:chararray, parameters:chararray);
log_lines = data.filter(lambda line: line.startswith("139.116.15.37,POSTEN"))
log_lines = log_lines.map(lambda l: l.split(","))

#logdata = log_lines.map(lambda p: Row(ip=p[0], user=p[1], date=p[2], time=p[3]))
logdata = log_lines.map(lambda p: [p[0], p[1], p[2], p[3]])
print logdata.count()
# Out:
# 811

# %%
schemaString = "ip user date time"
fields = [StructField(field_name, StringType(), True) for field_name in schemaString.split()]
schema = StructType(fields)
print schema
#logdata_df = sqlContext.createDataFrame(logdata, schema)

# Register the DataFrame as a table
#logdata_df.registerTempTable('logdata')

# SQL can be run over DataFrames that have been registered as a table
#results = sqlContext.sql('SELECT * FROM logdata LIMIT 10')
# Out:
# StructType(List(StructField(ip,StringType,true),StructField(user,StringType,true),StructField(date,StringType,true),StructField(time,StringType,true)))

# %%
# Small test with cache()
def isComment(line):
    return line.strip().startswith('/')

def isEmbeddedComment(line):
    return ('//' in line) or ('/*' in line)

myLines = sc.textFile('file:///c:/coding/c_kode/ScaleGeneratorMenu.c', 4).cache()
# Cache above, so that the filter() operation in next step doesen't have to reload the file from disk
print 'Total lines in file:', myLines.count()
commentLines1 = myLines.filter(isComment)
commentLines2 = myLines.filter(lambda x: x.strip().startswith('/'))
commentLinesEmbedded = myLines.filter(isEmbeddedComment)
print 'Line comment lines in file, version 1:', commentLines1.count()
print 'Line comment lines in file, version 2:', commentLines2.count()
print 'Embedded comment lines in file:', commentLinesEmbedded.count()
# Out:
# Total lines in file:
# 537
# Line comment lines in file, version 1:
# 34
# Line comment lines in file, version 2:
# 34
# Embedded comment lines in file:
# 50

# %%
# TODO: Try Spark 1.4 window functions:
# https://databricks.com/blog/2015/07/15/introducing-window-functions-in-spark-sql.html
from pyspark.sql.window import Window

# %%
# SERDE formats:
# http://wiki.apache.org/hadoop/Hive/DeveloperGuide
# a = LOAD 'iis.log' USING PigStorage(' ') AS
# (date:chararray, time:chararray, s_ip:chararray, cs_method:chararray, cs_uri_stem:chararray,
#     cs_uri_query:chararray, s_port:chararray, cs_username:chararray, c_ip:chararray,
#     cs_user_agent:chararray, sc_status:chararray, sc_substatus:chararray,
#    sc_win32_status:chararray);

# from pyspark.sql import HiveContext
sqlContext = HiveContext(sc)
# http://spark.apache.org/docs/latest/sql-programming-guide.html#hive-tables

# NOTE: You must build Spark with Hive:
# SET spark_hive=true
# run build/sbt assembly

sqlContext.sql("DROP TABLE IF EXISTS access_logs")

sqlContext.sql("CREATE EXTERNAL TABLE access_logs (date STRING, time STRING, s_ip STRING, cs_method STRING, " + \
               "cs_uri_stem STRING, cs_uri_query STRING, s_port STRING, cs_username STRING, c_ip STRING, " + \
               "cs_user_agent STRING, sc_status STRING, sc_substatus STRING, sc_win32_status STRING) " + \
               "ROW FORMAT SERDE 'org.apache.hadoop.hive.serde2.RegexSerDe' " + \
               "WITH SERDEPROPERTIES('input.regex'='^(\\S+) (\\S+) (\\S+) (\\S+) (\\S+) (\\S+) (\\S+) (\\S+) " + \
               "(\\S+) (\\S+) (\\S+) (\\S+) (\\S+)', " + \
               "'output.format.string'='%1$s %2$s %3$s %4$s %5$s %6$s %7$ %8$ %9$ %10$ %11$ %12$ %13$' )" + \
               "STORED AS TEXTFILE LOCATION '/user/terje/iis.log'")

#sqlContext.sql("IMPORT EXTERNAL TABLE access_logs FROM '/home/vagrant/data/terje/iis.log' " + \
#               "LOCATION '/home/vagrant/data/terje/access_logs'")

#sqlContext.sql("LOAD DATA LOCAL INPATH '/home/vagrant/data/terje/iis.log' OVERWRITE INTO TABLE access_logs")
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# <ipython-input-2-468c1ad99f13> in <module>()
#      15 # run build/sbt assembly
#      16
# ---> 17 sqlContext.sql("DROP TABLE IF EXISTS access_logs")
#      18
# ...

# %%
usernames = sqlContext.sql("SELECT * FROM access_logs")
usernames.head()
