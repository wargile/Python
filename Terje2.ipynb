# %%
# ReadCSV.py

# Name data: http://www.ssa.gov/oact/babynames/limits.html
#            http://www.ssa.gov/oact/babynames/names.zip

import csv
import os
import pprint
import operator
import matplotlib.pyplot as plt
import numpy as np
import pylab


def sort_and_display(the_names, sex):
    freq = []
    names = []
    max_names = 10
    sorted_names = sorted(the_names.iteritems(), key=operator.itemgetter(1), reverse=True)

    print "Top ten:\n--------"

    for disp_names in sorted_names[0:max_names]:
        freq.append(disp_names[1])
        names.append(disp_names[0])
        print disp_names

    fig, ax = plt.subplots()
    ax.bar(range(0, max_names), freq, color='r')
    ax.set_title('%s names' % sex)
    ax.set_xticks(range(0, max_names))
    ax.set_xticklabels(names, rotation=25, ha='center')
    ax.grid(True)
    plt.show()
    return(names[0:5]) # Display just six lines to avoid color repetition

def display_trend(popular_names, sex):
    start_year = 1880
    end_year = 2013
    name_trend = {}

    for n in popular_names:
        name_trend[n] = []

    for f in files:
        if f.endswith('.txt'):
            #print "Reading %s..." % f
            with open('C:/coding/R/TestData/US_BabyNames/BabyNames/%s' % f, 'rb') as f:
                reader = csv.reader(f, delimiter=',', quoting=csv.QUOTE_NONE)
                for row in reader:
                    if row[0] in name_trend and row[1] == sex:
                        name_trend[row[0]].append(int(row[2]))

    legend_names = []

    fig, axes = plt.subplots()

    for f in name_trend.values():
        #print f
        plt.plot(f)

    for f in name_trend:
        legend_names.append(f)

    # TODO: Dynamic vars for start and stop years
    years = np.arange(start=0, stop=(end_year - start_year),
                      step=round((end_year - start_year) / 10))
    years_int = []
    for y in years:
        years_int.append(int(y) + start_year)

    # Colors: https://pythonhosted.org/ete2/reference/reference_svgcolors.html
    #plt.gca().set_color_cycle(['red', 'green', 'blue', 'yellow', 'brown', 'magenta', 'cyan', 'gray', 'lightsalmon', 'black'])
    
    if sex == "M":
        plt.title('Popular male names{0}-{1}'.format(start_year, end_year))
    else:
        plt.title('Popular female names {0}-{1}'.format(start_year, end_year))
        
    leg = plt.legend(legend_names, loc='upper right', fancybox=True, shadow=True, prop={'size':8})
    for legobj in leg.legendHandles:
        legobj.set_linewidth(2.0)
        plt.xticks(years)
    #axes.set_xticks(np.linspace(start=0, stop=len(fname_trend.values()), num=10))
    axes.set_xticklabels(years_int, rotation=25, ha='center')
    plt.grid(True)
    plt.show()

fnames = {}
mnames = {}

# %matplotlib inline
# pylab.rcParams['figure.figsize'] = (10.0, 8.0)
# For iPython notebook

pp = pprint.PrettyPrinter(indent=1)

files = os.listdir('C:/coding/R/TestData/US_BabyNames/BabyNames')

#for f in files:
#    print f
    
for f in files:
    if f.endswith('.txt'):
        #print "Reading %s..." % f
        with open('C:/coding/R/TestData/US_BabyNames/BabyNames/%s' % f, 'rb') as f:
            reader = csv.reader(f, delimiter=',', quoting=csv.QUOTE_NONE)
            for row in reader:
                if row[1] == "M":
                    if row[0] in mnames:
                        mnames[row[0]] += int(row[2])
                    else:
                        mnames[row[0]] = int(row[2])
                else:
                    if row[0] in fnames:
                        fnames[row[0]] += int(row[2])
                    else:
                        fnames[row[0]] = int(row[2])

# pp.pprint(fnames)
# for names in fnames:
#    print fnames

popular_fnames = sort_and_display(fnames, 'Female')
popular_mnames = sort_and_display(mnames, 'Male')

display_trend(popular_fnames, "F")
display_trend(popular_mnames, "M")
# Out:
# Top ten:
# --------
# ('Mary', 4112464)
# ('Elizabeth', 1591439)
# ('Patricia', 1570135)
# ('Jennifer', 1461186)
# ('Linda', 1450328)
# ('Barbara', 1432543)
# ('Margaret', 1238016)
# ('Susan', 1120083)
# ('Dorothy', 1105281)
# ('Sarah', 1055860)
# Top ten:
# --------
# ('James', 5091189)
# ('John', 5073958)
# ('Robert', 4789776)
# ('Michael', 4293460)
# ('William', 4038447)
# ('David', 3565229)
# ('Joseph', 2557792)
# ('Richard', 2552302)
# ('Charles', 2356886)
# ('Thomas', 2275889)

# %%
x = ['This', 'is', 'a', 'list!']
x
for y in x:
    print y
# Out:
# This
# is
# a
# list!
